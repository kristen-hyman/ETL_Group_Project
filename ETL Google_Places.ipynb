# %%
# Dependencies
import requests
import json
import pprint
import pandas as pd
from sqlalchemy import create_engine
# Imports the methods needed to abstract classes into tables
from sqlalchemy.ext.declarative import declarative_base

# Allow us to declare column types
from sqlalchemy import Column, Integer, String, Float 

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()


# Google developer API key
gkey = "AIzaSyDAEB_F62yfnzmwI-EuFL_gFmG8ApMyEEI"
gkey2 = "AIzaSyAHJeSZuswKRGpJsrVyBDhb3pvo3CeDsRM"

# %%
Restaurant_Results = []
token_list = []



    # geocoordinates
    target_coordinates = "38.89950, -77.021719" #Penn Quarter
    target_radius = 1600
    target_type = "restaurant"

    # set up a parameters dictionary
    params = {
        "location": target_coordinates,
        "radius": target_radius,
        "type": target_type,
        "key": gkey
    }

    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
    response = requests.get(base_url, params=params)

    places_data = response.json()
    token = (places_data["next_page_token"])
    token_list.append({"Token": token})
    
    for item in places_data["results"]:
        name = (item["name"])
        address = (item["vicinity"])
        rating = (item["rating"])
        
        if name not in Restaurant_Results:
            Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})
    print(name)
# Out:
# Lincoln's Waffle Shop

# %%
    # geocoordinates
target_coordinates = "38.899501, -77.021719" #Penn Quarter
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
    "pagetoken": token
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
    #token = (places_data["next_page_token"])
    #token_list.append({"Token": token})
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
            Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})
# Out:
#   File "<ipython-input-200-472ce20ba7c2>", line 3
#     target_coordinates = "38.899501, -77.021719" #Penn Quarter
#     ^
# IndentationError: unexpected indent

# %%
# geocoordinates
target_coordinates = "38.978423, -77.023703" #NorthernDC - Takoma
target_radius = 1600
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
token2 = (places_data["next_page_token"])

for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                             "Address": address,
                             "Rating": rating})
print(name)
# Out:
# Manny & Olga’s Pizza - Silver Spring

# %%
# geocoordinates
target_coordinates = "38.978423, -77.023703" #NorthernDC - Takoma
target_radius = 1600
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
    "pagetoken": token2
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()

for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                             "Address": address,
                             "Rating": rating})

# %%
# geocoordinates
target_coordinates = "38.901565, -76.994709" #H Street area
target_radius = 1600
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
token3 = (places_data["next_page_token"])

for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                             "Address": address,
                             "Rating": rating})

# %%
# geocoordinates
target_coordinates = "38.901565, -76.994709" #H Street area
target_radius = 1600
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
    "pagetoken": token3
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()

for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                             "Address": address,
                             "Rating": rating})

# %%
# geocoordinates
target_coordinates = "38.875244, -77.012739" #SW Waterfront
target_radius = 1600
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
token4 = (places_data["next_page_token"])

for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                             "Address": address,
                             "Rating": rating})

# %%
# geocoordinates
target_coordinates = "38.875244, -77.012739" #SW Waterfront
target_radius = 1600
target_type = "restaurant"

# set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
    "pagetoken": token4
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()

for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                             "Address": address,
                             "Rating": rating})

# %%
# geocoordinates
target_coordinates = "38.907978, -77.067677" #Georgetown
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
token5 = (places_data["next_page_token"])
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])
        
    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})

# %%
    # geocoordinates
target_coordinates = "38.907978, -77.067677" #Georgetown
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
    "pagetoken": token5
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})

# %%
# geocoordinates
target_coordinates = "38.948490, -77.080827" #Tenleytown
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
token6 = (places_data["next_page_token"])
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])
        
    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})

# %%
    # geocoordinates
target_coordinates = "38.948490, -77.080827" #Tenleytown
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
    "pagetoken": token6
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})

# %%
# geocoordinates
target_coordinates = "38.921244, -77.047867" #Adams Morgan
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
token7 = (places_data["next_page_token"])
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])
        
    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})

# %%
    # geocoordinates
target_coordinates = "38.921244, -77.047867" #Adams Morgan
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
    "pagetoken": token7
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})

# %%
# geocoordinates
target_coordinates = "38.894826, -77.072799" #Rosslyn
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
token8 = (places_data["next_page_token"])
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])
        
    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})

# %%
    # geocoordinates
target_coordinates = "38.894826, -77.072799" #Rosslyn
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
    "pagetoken": token8
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})

# %%
# geocoordinates
target_coordinates = "38.886499, -77.094348" #Courthouse
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
token9 = (places_data["next_page_token"])
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])
        
    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})

# %%
    # geocoordinates
target_coordinates = "38.886499, -77.094348" #Courthouse
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey,
    "pagetoken": token9
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])

    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})

# %%
# geocoordinates
target_coordinates = "338.886499, -77.094348" #Clarendon
target_radius = 1600
target_type = "restaurant"

    # set up a parameters dictionary
params = {
    "location": target_coordinates,
    "radius": target_radius,
    "type": target_type,
    "key": gkey2
    }

    # base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
response = requests.get(base_url, params=params)

places_data = response.json()
#token10 = (places_data["next_page_token"])
print(json.dumps(places_data, indent=4, sort_keys=True))
    
for item in places_data["results"]:
    name = (item["name"])
    address = (item["vicinity"])
    rating = (item["rating"])
        
    if name not in Restaurant_Results:
        Restaurant_Results.append({"Restaurant Name": name,
                                 "Address": address,
                                 "Rating": rating})
# Out:
# {
#     "html_attributions": [],
#     "results": [],
#     "status": "INVALID_REQUEST"
# }

# %%
# convert response to json
pprint.pprint(Restaurant_Results)
# Out:
# [{'Address': '520 North Capitol Street Northwest, Washington',
#   'Rating': 4.3,
#   'Restaurant Name': 'Phoenix Park Hotel'},
#  {'Address': '1201 Pennsylvania Avenue Northwest, Washington',
#   'Rating': 4,
#   'Restaurant Name': 'Elephant & Castle'},
#  {'Address': '675 15th Street Northwest, Washington',
#   'Rating': 4.5,
#   'Restaurant Name': 'Old Ebbitt Grill'},
#  {'Address': '1620 I Street Northwest, Washington',
#   'Rating': 4,
#   'Restaurant Name': 'Blackfinn Ameripub'},
#  {'Address': '1309 F Street Northwest, Washington',
#   'Rating': 4.3,
#   'Restaurant Name': 'District Taco - Metro Center'},
#  {'Address': '600 14th Street Northwest, Washington',
#   'Rating': 4.4,
#   'Restaurant Name': 'The Hamilton'},
#  {'Address': '633 D Street Northwest, Washington',
#   'Rating': 4.3,
#   'Restaurant Name': 'Rasika'},
#  {'Address': '701 9th Street Northwest, Washington',
#   'Rating': 4.5,
#   'Restaurant Name': 'Zaytinya'},
# ...

# %%
print(len(Restaurant_Results))
# Out:
# 340

# %%
GoogleDF = pd.DataFrame.from_dict(Restaurant_Results)
DF2 = GoogleDF.rename(columns={"Restaurant Name":"RestaurantName"})


FinalDF = DF2[["RestaurantName","Address","Rating"]]
FinalDF.head()
# Out:
#                  RestaurantName  \
# 0            Phoenix Park Hotel
# 1             Elephant & Castle
# 2              Old Ebbitt Grill
# 3            Blackfinn Ameripub
# 4  District Taco - Metro Center
#
#                                           Address  Rating
# 0  520 North Capitol Street Northwest, Washington     4.3
# 1  1201 Pennsylvania Avenue Northwest, Washington     4.0
# 2           675 15th Street Northwest, Washington     4.5
# 3             1620 I Street Northwest, Washington     4.0
# 4             1309 F Street Northwest, Washington     4.3

# %%
connection = "root:kristen@localhost:3306/KH_ETL_Project"
engine = create_engine(f'mysql://{connection}')

# %%
engine.table_names()
# Out:
# ['Restaurant_Info']

# %%
FinalDF.to_sql(name='Restaurant_Info',con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from Restaurant_Info', con=engine).head()
# Out:
#                  RestaurantName  \
# 0            Phoenix Park Hotel
# 1             Elephant & Castle
# 2              Old Ebbitt Grill
# 3            Blackfinn Ameripub
# 4  District Taco - Metro Center
#
#                                           Address Rating
# 0  520 North Capitol Street Northwest, Washington    4.3
# 1  1201 Pennsylvania Avenue Northwest, Washington      4
# 2           675 15th Street Northwest, Washington    4.5
# 3             1620 I Street Northwest, Washington      4
# 4             1309 F Street Northwest, Washington    4.3
